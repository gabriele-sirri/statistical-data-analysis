# %%
import ROOT

# define observable
x = ROOT.RooRealVar('x', 'observable', -20, 20)   # range -20,20 

#define constants
m = ROOT.RooRealVar('m', 'mean', 0) # mean fixed to 0 and shared by both Gaussians
s1 = ROOT.RooRealVar('s1', 's1', 3.123) # constant

# parameters
s2 = ROOT.RooRealVar('s2', 's2', 4, 3, 6) # parameter
f = ROOT.RooRealVar('f', 'f', 0.5, 0, 1)

# model
gaus1 = ROOT.RooGaussian('g1', 'g1', x, m, s1)
gaus2 = ROOT.RooGaussian('g2', 'g2', x, m, s2)

model = ROOT.RooAddPdf('model', 'my model', 
                       ROOT.RooArgList(gaus1, gaus2),
                       ROOT.RooArgList(f))
# Out:
# [#0] WARNING:InputArguments -- The parameter 's1' with range [-inf, inf] of the RooGaussian 'g1' exceeds the safe range of (0, inf). Advise to limit its range.

# %%
# Generate an unbinned dataset data of 1000 events from the model
data = model.generate(x, 1000)
# save a workspace
w = ROOT.RooWorkspace('w')
w.Import(model)
w.Import(data)

w.writeToFile('test.root')

w.Print()
# Out:
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooAddPdf::model
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooGaussian::g1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::x
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::m
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::s1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::f
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooGaussian::g2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::s2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing dataset modelData
#
# RooWorkspace(w) w contents
#
# variables
# ---------
# (f,m,s1,s2,x)
#
# p.d.f.s
# -------
# RooGaussian::g1[ x=x mean=m sigma=s1 ] = 1
# RooGaussian::g2[ x=x mean=m sigma=s2 ] = 1
# RooAddPdf::model[ f * g1 + [%] * g2 ] = 1/1
#
# datasets
# --------
# RooDataSet::modelData(x)

# %%
# minimize the Negative Log-Likelihood

# create a NLL function
nll = model.createNLL(data)

# create an MINUIT instance
minuit = ROOT.RooMinimizer(nll)
f.Print()
s2.Print()
# Out:
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- using generic CPU library compiled with no vectorizations
# [#1] INFO:Fitting -- Creation of NLL object took 26.2756 ms
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_model_modelData) Summation contains a RooNLLVar, using its error level
# RooRealVar::f = 0.5  L(0 - 1)
# RooRealVar::s2 = 4  L(3 - 6)

# %%
# run migrad
minuit.setVerbose(True)
minuit.migrad()
minuit.setVerbose(False)
# Out:
# [#0] WARNING:Minimization -- RooAbsMinimizerFcn::synchronize: WARNING: no initial error estimate available for f: using 0.1
# [#0] WARNING:Minimization -- RooAbsMinimizerFcn::synchronize: WARNING: no initial error estimate available for s2: using 0.3
# Minuit2Minimizer: Minimize with max-calls 1000 convergence for edm < 1 strategy 1
#
# prevFCN = 2676.199131  f=0.5036,
# prevFCN = 2676.16544  f=0.4964,
# prevFCN = 2676.234176  f=0.5, s2=4.011,
# prevFCN = 2676.255652  s2=3.989,
# prevFCN = 2676.147798  s2=4.005,
# prevFCN = 2676.22652  s2=3.995,
# prevFCN = 2676.173019  f=0.5908, s2=3.889,
# prevFCN = 2676.128545  f=0.5479, s2=3.941,
# prevFCN = 2675.837398  f=0.5514,
# prevFCN = 2675.835945  f=0.5445,
# prevFCN = 2675.840102  f=0.5479, s2=3.947,
# prevFCN = 2675.834084  s2=3.936,
# prevFCN = 2675.841857  f=0.5551, s2=3.955,
# prevFCN = 2675.82355  f=0.5837, s2=4.01,
# prevFCN = 2675.776595  f=0.6536, s2=4.151,
# prevFCN = 2675.720524  f=0.6632, s2=4.171,
# prevFCN = 2675.721537  f=0.657, s2=4.151,
# prevFCN = 2675.722624  f=0.6502,
# prevFCN = 2675.720257  f=0.6536, s2=4.157,
# prevFCN = 2675.719899  s2=4.145,
# prevFCN = 2675.722077  f=0.6539, s2=4.157,
# prevFCN = 2675.719886  f=0.654, s2=4.158,
# prevFCN = 2675.719864  f=0.6567,
# prevFCN = 2675.720335  f=0.6512,
# prevFCN = 2675.720682  f=0.654, s2=4.165,
# prevFCN = 2675.720516  s2=4.152,
# prevFCN = 2675.720483  s2=4.158,
# prevFCN = 2675.719864  f=0.6567,
# prevFCN = 2675.720335  f=0.6512,
# prevFCN = 2675.720682  f=0.654, s2=4.165,
# prevFCN = 2675.720516  s2=4.152,
# prevFCN = 2675.720483  f=0.6545, s2=4.158,
# prevFCN = 2675.719855  f=0.6534,
# prevFCN = 2675.719924  f=0.654, s2=4.16,
# prevFCN = 2675.719893  s2=4.157,
# prevFCN = 2675.719886  f=0.6567, s2=4.165,
# prevFCN = 2675.719815  Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = 2675.71986383874309
# Edm   = 6.00237350052438268e-05
# Nfcn  = 37
# f	  = 0.654	 +/-  0.1888	(limited)
# s2	  = 4.158	 +/-  0.4712	(limited)
# f=0.654, s2=4.158,
# Info in <Minuit2>: MnSeedGenerator Computing seed using NumericalGradient calculator
# Info in <Minuit2>: MnSeedGenerator Evaluated function and gradient in 1.18307 ms
# Info in <Minuit2>: MnSeedGenerator Initial state: FCN =       2676.199131 Edm =      0.7164695953 NCalls =      7
# Info in <Minuit2>: MnSeedGenerator Initial state
#   Minimum value : 2676.199131
#   Edm           : 0.7164695953
#   Internal parameters:	[                0    -0.3398369095]
#   Internal gradient  :	[     -4.777507061      7.040591328]
#   Internal covariance matrix:
# [[    0.076436372              0]
#  [              0    0.022619577]]]
# Info in <Minuit2>: VariableMetricBuilder Start iterating until Edm is < 0.001 with call limit = 1000
# Info in <Minuit2>: VariableMetricBuilder    0 - FCN =       2676.199131 Edm =      0.7164695953 NCalls =      7
# Info in <Minuit2>: VariableMetricBuilder    1 - FCN =       2675.837398 Edm =    0.007610977017 NCalls =     13
# Info in <Minuit2>: VariableMetricBuilder    2 - FCN =       2675.720524 Edm =   0.0004946533062 NCalls =     21
# Info in <Minuit2>: VariableMetricBuilder    3 - FCN =       2675.719864 Edm =   8.582247772e-05 NCalls =     27
# Info in <Minuit2>: MnHesse Done after 743.42 μs
# Info in <Minuit2>: VariableMetricBuilder After Hessian
# Info in <Minuit2>: VariableMetricBuilder    4 - FCN =       2675.719864 Edm =   6.002373501e-05 NCalls =     37
# Info in <Minuit2>: VariableMetricBuilder Stop iterating after 2.73121 ms

# %%
# print 'f' and 's2' values after MIGRAD
f.Print()
s2.Print()
# Out:
# RooRealVar::f = 0.654 +/- 0.1888  L(0 - 1)
# RooRealVar::s2 = 4.158 +/- 0.4712  L(3 - 6)

# %%
# run HESSE Error Calculation
minuit.hesse()
# Out:
# 0
# Info in <Minuit2>: Minuit2Minimizer::Hesse Using max-calls 1000
# Info in <Minuit2>: MnHesse Done after 1.09248 ms
# Info in <Minuit2>: Minuit2Minimizer::Hesse Hesse is valid - matrix is accurate

# %%
# print 'f' and 's2' values after HESSE
f.Print()
s2.Print()
# Out:
# RooRealVar::f = 0.654 +/- 0.1893  L(0 - 1)
# RooRealVar::s2 = 4.158 +/- 0.4725  L(3 - 6)

# %%
# run minos
minuit.minos(s2)
# Out:
# 0
# ******************************************************************************************************
# Minuit2Minimizer::GetMinosError - Run MINOS LOWER error for parameter #1 : s2 using max-calls 1000, tolerance 1
# ******************************************************************************************************
# Minuit2Minimizer::GetMinosError - Run MINOS UPPER error for parameter #1 : s2 using max-calls 1000, tolerance 1
# Minos: Lower error for parameter s2  :  -0.4393
# Minos: Upper error for parameter s2  :  0.5432
# Info in <Minuit2>: MnMinos Determination of lower Minos error for parameter 1
# Info in <Minuit2>: MnFunctionCross Run Migrad with fixed parameters:
#   Pos 1: s2 = 3.68588
# Info in <Minuit2>: MnSeedGenerator Computing seed using NumericalGradient calculator
# Info in <Minuit2>: MnSeedGenerator Evaluated function and gradient in 654.471 μs
# Info in <Minuit2>: MnSeedGenerator Initial state: FCN =       2676.730679 Edm =      0.1577549671 NCalls =      3
# Info in <Minuit2>: MnSeedGenerator Initial state
#   Minimum value : 2676.730679
#   Edm           : 0.1577549671
#   Internal parameters:	[   -0.06213616385]
#   Internal gradient  :	[      3.427971276]
#   Internal covariance matrix:
# [[    0.053699308]]]
# Info in <Minuit2>: VariableMetricBuilder Start iterating until Edm is < 0.0005 with call limit = 1000
# Info in <Minuit2>: VariableMetricBuilder    0 - FCN =       2676.730679 Edm =      0.1577549671 NCalls =      3
# Info in <Minuit2>: VariableMetricBuilder    1 - FCN =       2676.303483 Edm =   0.0001366307071 NCalls =      8
# Info in <Minuit2>: VariableMetricBuilder Stop iterating after 884.493 μs
# Info in <Minuit2>: MnFunctionCross Result after Migrad FCN =       2676.303483 Edm =   0.0001366307071 NCalls =      8
#   Pos |    Name    |  type   |      Value       |    Error +/-
#     0 |          f | limited |     0.3456983014 | 0.1291407791
#     1 |         s2 |  fixed  |      3.685875252 | 0.4725395182
# Info in <Minuit2>: MnFunctionCross Run Migrad again (2nd) with fixed parameters:
#   Pos 1: s2 = 3.72104
# Info in <Minuit2>: MnSeedGenerator Computing seed using NumericalGradient calculator
# Info in <Minuit2>: MnSeedGenerator Evaluated function and gradient in 923.562 μs
# Info in <Minuit2>: MnSeedGenerator Initial state: FCN =       2676.250088 Edm =     0.03320418629 NCalls =      3
# Info in <Minuit2>: MnSeedGenerator Initial state
#   Minimum value : 2676.250088
#   Edm           : 0.03320418629
#   Internal parameters:	[    -0.3137244143]
#   Internal gradient  :	[     -0.937126838]
#   Internal covariance matrix:
# [[     0.15123631]]]
# Info in <Minuit2>: VariableMetricBuilder Start iterating until Edm is < 0.0005 with call limit = 1000
# Info in <Minuit2>: VariableMetricBuilder    0 - FCN =       2676.250088 Edm =     0.03320418629 NCalls =      3
# Info in <Minuit2>: VariableMetricBuilder    1 - FCN =       2676.215035 Edm =   1.364247853e-05 NCalls =      7
# Info in <Minuit2>: VariableMetricBuilder Stop iterating after 640.802 μs
# Info in <Minuit2>: MnFunctionCross Result after 2nd Migrad FCN =       2676.215035 Edm =   1.364247853e-05 NCalls =      7
#   Pos |    Name    |  type   |      Value       |    Error +/-
#     0 |          f | limited |     0.3817472874 | 0.1342549285
#     1 |         s2 |  fixed  |      3.721035367 | 0.4725395182
# Info in <Minuit2>: MnFunctionCross Return: Found good value for aopt =  -0.0703447
# Info in <Minuit2>: MnMinos end of Minos scan for low interval for parameter s2
# Info in <Minuit2>: MnMinos Determination of upper Minos error for parameter 1
# Info in <Minuit2>: MnFunctionCross Run Migrad with fixed parameters:
#   Pos 1: s2 = 4.63095
# Info in <Minuit2>: MnSeedGenerator Computing seed using NumericalGradient calculator
# Info in <Minuit2>: MnSeedGenerator Evaluated function and gradient in 509.724 μs
# Info in <Minuit2>: MnSeedGenerator Initial state: FCN =       2676.412763 Edm =      0.4638351458 NCalls =      5
# Info in <Minuit2>: MnSeedGenerator Initial state
#   Minimum value : 2676.412763
#   Edm           : 0.4638351458
#   Internal parameters:	[     0.6881173591]
#   Internal gradient  :	[      5.877971547]
#   Internal covariance matrix:
# [[    0.053699308]]]
# Info in <Minuit2>: VariableMetricBuilder Start iterating until Edm is < 0.0005 with call limit = 1000
# Info in <Minuit2>: VariableMetricBuilder    0 - FCN =       2676.412763 Edm =      0.4638351458 NCalls =      5
# Info in <Minuit2>: VariableMetricBuilder    1 - FCN =       2676.108923 Edm =   7.597518443e-10 NCalls =      9
# Info in <Minuit2>: VariableMetricBuilder Stop iterating after 409.554 μs
# Info in <Minuit2>: MnFunctionCross Result after Migrad FCN =       2676.108923 Edm =   7.597518443e-10 NCalls =      9
#   Pos |    Name    |  type   |      Value       |    Error +/-
#     0 |          f | limited |     0.7764404014 | 0.05480531178
#     1 |         s2 |  fixed  |      4.630954288 | 0.4725395182
# Info in <Minuit2>: MnFunctionCross Run Migrad again (2nd) with fixed parameters:
#   Pos 1: s2 = 4.69411
# Info in <Minuit2>: MnSeedGenerator Computing seed using NumericalGradient calculator
# Info in <Minuit2>: MnSeedGenerator Evaluated function and gradient in 174.634 μs
# Info in <Minuit2>: MnSeedGenerator Initial state: FCN =       2676.229369 Edm =     0.02361623689 NCalls =      3
# Info in <Minuit2>: MnSeedGenerator Initial state
#   Minimum value : 2676.229369
#   Edm           : 0.02361623689
#   Internal parameters:	[     0.5858175546]
#   Internal gradient  :	[     -1.647357644]
#   Internal covariance matrix:
# [[    0.034809268]]]
# Info in <Minuit2>: VariableMetricBuilder Start iterating until Edm is < 0.0005 with call limit = 1000
# Info in <Minuit2>: VariableMetricBuilder    0 - FCN =       2676.229369 Edm =     0.02361623689 NCalls =      3
# Info in <Minuit2>: VariableMetricBuilder    1 - FCN =       2676.207561 Edm =   7.086070443e-08 NCalls =      7
# Info in <Minuit2>: VariableMetricBuilder Stop iterating after 199.32 μs
# Info in <Minuit2>: MnFunctionCross Result after 2nd Migrad FCN =       2676.207561 Edm =   7.086070443e-08 NCalls =      7
#   Pos |    Name    |  type   |      Value       |    Error +/-
#     0 |          f | limited |      0.787376832 | 0.05178656969
#     1 |         s2 |  fixed  |      4.694107094 | 0.4725395182
# Info in <Minuit2>: MnFunctionCross Run Migrad again (3rd) with fixed parameters:
#   Pos 1: s2 = 4.70198
# Info in <Minuit2>: MnSeedGenerator Computing seed using NumericalGradient calculator
# Info in <Minuit2>: MnSeedGenerator Evaluated function and gradient in 162.393 μs
# Info in <Minuit2>: MnSeedGenerator Initial state: FCN =       2676.220753 Edm =   0.0003268867429 NCalls =      3
# Info in <Minuit2>: MnSeedGenerator Initial state
#   Minimum value : 2676.220753
#   Edm           : 0.0003268867429
#   Internal parameters:	[     0.6123030922]
#   Internal gradient  :	[    -0.2014775843]
#   Internal covariance matrix:
# [[    0.032210972]]]
# Info in <Minuit2>: VariableMetricBuilder Start iterating until Edm is < 0.0005 with call limit = 1000
# Info in <Minuit2>: VariableMetricBuilder    0 - FCN =       2676.220753 Edm =   0.0003268867429 NCalls =      3
# Info in <Minuit2>: VariableMetricBuilder    1 - FCN =       2676.220427 Edm =   2.482556864e-12 NCalls =      6
# Info in <Minuit2>: VariableMetricBuilder Stop iterating after 166.882 μs
# Info in <Minuit2>: MnFunctionCross Result after Migrad (3rd): FCN =       2676.220427 Edm =   2.482556864e-12 NCalls =      6
#   Pos |    Name    |  type   |      Value       |    Error +/-
#     0 |          f | limited |     0.7887030083 | 0.05167051197
#     1 |         s2 |  fixed  |      4.701984281 | 0.4725395182
# Info in <Minuit2>: MnMinos end of Minos scan for up interval for parameter s2

# %%
# print 'f' and 's2' values after HESSE

f.Print()
s2.Print()
fit_results = minuit.save()

fit_results.Print('v')
# Out:
# RooRealVar::f = 0.654 +/- 0.1893  L(0 - 1)
# RooRealVar::s2 = 4.158 +/- (-0.4393,0.5432)  L(3 - 6)
#
#   RooFitResult: minimized FCN value: 2676, estimated distance to minimum: 6.036e-05
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MIGRAD=0 HESSE=0 MINOS=0
#
#     Constant Parameter    Value
#   --------------------  ------------
#                      m    0.0000e+00
#                     s1    3.1230e+00
#
#     Floating Parameter  InitialValue    FinalValue (+HiError,-LoError)    GblCorr.
#   --------------------  ------------  ----------------------------------  --------
#                      f    5.0000e-01    6.5395e-01         +/-  1.89e-01  <none>
#                     s2    4.0000e+00    4.1584e+00 (+5.43e-01,-4.39e-01)  <none>

# %%
# Access the correlation matrix as TMatrixDSym
cor_matrix = fit_results.correlationMatrix()
print("Correlation matrix:")
cor_matrix.Print()
# Out:
# Correlation matrix:
#
# 2x2 matrix is as follows
#
#      |      0    |      1    |
# -------------------------------
#    0 |          1      0.9164
#    1 |     0.9164           1

# %%
#  Visualize the correlation matrix 
 
c = ROOT.TCanvas()

fit_results.correlationHist().Draw('colZ')
c.Draw()
# Out:
# <div id="root_plot_1764454112630" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1764454112630(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.250000018626453,"fY1":-0.250000018626453,"fX2":2.25000001862645,"fY2":2.25000001862645,"fXtoAbsPixelk":69.6000041484835,"fXtoPixelk":69.6000041484835,"fXtoPixel":278.399995851517,"fYtoAbsPixelk":424.799997186661,"fYtoPixelk":424.799997186661,"fYtoPixel":-188.799997186661,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":696,"fVtoAbsPixelk":472,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-0.250000018626453,"fPixeltoXk":-0.250000018626453,"fPixeltoX":0.00359195407651279,"fAbsPixeltoYk":2.25000001862645,"fPixeltoYk":-0.250000018626453,"fPixeltoY":-0.00529661024841717,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":2,"fUymax":2,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c1","fTitle":"c1","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":14.28571,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":696,"fCh":472,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fClassName":"","fObjectName":"","fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33,221;109:24,69,251;110:255,94,2 ...

# %%
c = ROOT.TCanvas()

# Access the covariance matrix as TMatrixDSym
cov_matrix = fit_results.covarianceMatrix()
print("Covariance matrix:")
cov_matrix.Print()

fit_results.covarianceMatrix().Draw('colZ')
c.Draw()
# Out:
# Covariance matrix:
#
# 2x2 matrix is as follows
#
#      |      0    |      1    |
# -------------------------------
#    0 |    0.03792     0.08587
#    1 |    0.08587      0.2316
# <div id="root_plot_1764454163563" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1764454163563(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.250000018626453,"fY1":-0.250000018626453,"fX2":2.25000001862645,"fY2":2.25000001862645,"fXtoAbsPixelk":69.6000041484835,"fXtoPixelk":69.6000041484835,"fXtoPixel":278.399995851517,"fYtoAbsPixelk":424.799997186661,"fYtoPixelk":424.799997186661,"fYtoPixel":-188.799997186661,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":696,"fVtoAbsPixelk":472,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-0.250000018626453,"fPixeltoXk":-0.250000018626453,"fPixeltoX":0.00359195407651279,"fAbsPixeltoYk":2.25000001862645,"fPixeltoYk":-0.250000018626453,"fPixeltoY":-0.00529661024841717,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":2,"fUymax":2,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c1_n4","fTitle":"c1_n4","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":14.28571,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":696,"fCh":472,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fClassName":"","fObjectName":"","fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33,221;109:24,69,251;110:25 ...

# %%
# Contour Plot

frame = minuit.contour(f, s2, 1, 2, 3)

c2 = ROOT.TCanvas()
frame.Draw()
c2.Draw()
# Out:
# Info in <Minuit2>: Minuit2Minimizer::Contour Computing contours at level - 0.5
# Info in <Minuit2>: Minuit2Minimizer::Contour  Computed 50 points at level 0.5
# ( 0.359713, 3.73618) ( 0.379066, 3.7191) ( 0.41257, 3.72689) ( 0.443645, 3.74164) ( 0.472772, 3.75962)
# ( 0.500301, 3.77997) ( 0.52612, 3.80208) ( 0.550436, 3.82584) ( 0.573252, 3.85104) ( 0.594581, 3.87751)
# ( 0.614223, 3.90476) ( 0.632477, 3.93295) ( 0.649395, 3.96197) ( 0.66504, 3.99169) ( 0.679475, 4.02199)
# ( 0.692782, 4.05281) ( 0.716311, 4.11567) ( 0.735707, 4.17804) ( 0.75212, 4.24126) ( 0.765935, 4.30509)
# ( 0.777449, 4.36938) ( 0.786855, 4.43399) ( 0.794217, 4.49887) ( 0.799374, 4.56396) ( 0.801555, 4.62923)
# ( 0.788718, 4.70164) ( 0.768528, 4.67493) ( 0.75552, 4.64408) ( 0.732824, 4.58163) ( 0.71136, 4.51902)
# ( 0.68976, 4.45645) ( 0.667743, 4.39411) ( 0.644938, 4.33206) ( 0.621133, 4.27038) ( 0.609681, 4.23935)
# ( 0.596159, 4.20916) ( 0.58413, 4.17833) ( 0.569865, 4.14848) ( 0.557157, 4.11792) ( 0.542141, 4.08843)
# ( 0.528657, 4.05821) ( 0.512908, 4.02911) ( 0.49856, 3.9993) ( 0.482154, 3.97056) ( 0.466867, 3.94122)
# ( 0.449983, 3.91276) ( 0.433735, 3.88395) ( 0.416812, 3.85552) ( 0.399644, 3.82714) ( 0.383873, 3.79795)
#
#
# Info in <Minuit2>: Minuit2Minimizer::Contour Computing contours at level - 2
# Info in <Minuit2>: Minuit2Minimizer::Contour  Computed 50 points at level 2
# ( 0, 3.62285) ( 0, 3.41842) ( 4.90137e-07, 3.41842) ( 0.0693655, 3.43496) ( 0.138159, 3.45374)
# ( 0.206183, 3.47516) ( 0.273138, 3.49973) ( 0.338784, 3.52809) ( 0.402381, 3.56078) ( 0.463221, 3.59842)
# ( 0.520392, 3.64143) ( 0.573441, 3.69041) ( 0.621049, 3.74469) ( 0.662805, 3.80357) ( 0.698779, 3.86615)
# ( 0.755123, 3.99836) ( 0.795434, 4.1363) ( 0.822852, 4.26773) ( 0.843291, 4.40043) ( 0.858662, 4.53378)
# ( 0.870238, 4.66751) ( 0.878832, 4.80137) ( 0.884938, 4.93538) ( 0.888735, 5.06946) ( 0.889975, 5.2036)
# ( 0.887962, 5.31452) ( 0.871151, 5.42418) ( 0.8393, 5.33456) ( 0.818828, 5.24167) ( 0.79987, 5.14865)
# ( 0.779524, 5.05592) ( 0.762168, 4.96255) ( 0.73741, 4.87088) ( 0.714425, 4.77882) ( 0.689782, 4.68718)
# ( 0.663093, 4.59577) ( 0.634129, 4.50505) ( 0.602535, 4.41521) ( 0.567921, 4.32649) ( 0.529807, 4.2391)
# ( 0.487758, 4.15354) ( 0.441274, 4.07028) ( 0.389899, 3.98995) ( 0.350383, 3.93526) ( 0.308138, 3.88265)
# ( 0.263125, 3.83238) ( 0.215381, 3.7847) ( 0.165001, 3.7398) ( 0.112159, 3.69782) ( 0.0570755, 3.65885)
#
#
# Info in <Minuit2>: Minuit2Minimizer::Contour Computing contours at level - 4.5
# Info in <Minuit2>: Minuit2Minimizer::Contour  Computed 50 points at level 4.5
# ( 0, 3.73182) ( 0, 3.32414) ( 0.000209729, 3.32414) ( 0.0523415, 3.32934) ( 0.10258, 3.34419)
# ( 0.154791, 3.35014) ( 0.204021, 3.36852) ( 0.256344, 3.37573) ( 0.303975, 3.39856) ( 0.356148, 3.40832)
# ( 0.401328, 3.43618) ( 0.452884, 3.45145) ( 0.495399, 3.48437) ( 0.581983, 3.54498) ( 0.6576, 3.61902)
# ( 0.719641, 3.70475) ( 0.767006, 3.79604) ( 0.803584, 3.89216) ( 0.853737, 4.09131) ( 0.884827, 4.29358)
# ( 0.905199, 4.49722) ( 0.917988, 4.68203) ( 0.927256, 4.86705) ( 0.934061, 5.05217) ( 0.939066, 5.23735)
# ( 0.942689, 5.42254) ( 0.94519, 5.60776) ( 0.949945, 5.79296) ( 0.947265, 5.97821) ( 0.947259, 6)
# ( 0.859552, 6) ( 0.844953, 5.84605) ( 0.82243, 5.69306) ( 0.801274, 5.53992) ( 0.77788, 5.38711)
# ( 0.751802, 5.23469) ( 0.722523, 5.08285) ( 0.689397, 4.9318) ( 0.651628, 4.78183) ( 0.607345, 4.63068)
# ( 0.555862, 4.48183) ( 0.495501, 4.33627) ( 0.42435, 4.19568) ( 0.383819, 4.12748) ( 0.339821, 4.06146)
# ( 0.29218, 3.99802) ( 0.240811, 3.93755) ( 0.185701, 3.88041) ( 0.127015, 3.82695) ( 0.0650022, 3.77739)
# <div id="root_plot_1764454113237" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1764454113237(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.125000009313226,"fY1":2.62499997206032,"fX2":1.12500000931323,"fY2":6.37500002793968,"fXtoAbsPixelk":69.6000041484835,"fXtoPixelk":69.6000041484835,"fXtoPixel":556.799991703033,"fYtoAbsPixelk":802.399991559982,"fYtoPixelk":802.399991559982,"fYtoPixel":-125.866664791107,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":696,"fVtoAbsPixelk":472,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-0.125000009313226,"fPixeltoXk":-0.125000009313226,"fPixeltoX":0.0017959770382564,"fAbsPixeltoYk":6.37500002793968,"fPixeltoYk":2.62499997206032,"fPixeltoY":-0.00794491537262576,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":3,"fUxmax":1,"fUymax":6,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c1_n3","fTitle":"c1_n3","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":14.28571,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":696,"fCh":472,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fClassName":"","fObjectName":"","fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33,221;109:24,69,251;110:255,94, ...
